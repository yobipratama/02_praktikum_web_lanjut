# %% [markdown]
# <a href="https://colab.research.google.com/github/yobipratama/02_praktikum_web_lanjut/blob/master/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jobsheet 1
#
# Nama : Yoby Ryaian Pratama
#
# Nim : 2041720039

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls =  ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
         "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
         "https://placekitten.com/800/571"]
#Baca dan tampilkan image 
#loop pada tiap url image, beberpaimage dapat disimpan pada list

for url in urls :
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('/n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F18CAAC2F70>
# /n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F18BF00B550>
# /n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F18CAAC2F70>
# /n

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F18BEF62F10>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [400, 400, 400]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F18BEFD7DF0>

# %% [markdown]
# #Pertanyaan
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
#  dikarenakan google collab sendiri dapat berkolaborasi dengan bahasa pemrograman python maka dapat digunakan oleh penggunanya melalui beberapa koding secara online.
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#   - numpy adalah perpustakaan manipulasi array, digunakan untuk aljabar linier,transformasi fourier, dan kemampuan angka acak
#
#   - pandas adalah perpustakaan untuk manipulasi data dan analisis data.
#   - cv2 adalah perpustakaan untuk tugas visi komputer
#   - skimage adalah pustaka yang mendukung aplikasi pengolah gambar di python
#   - matlotlib library Python yang fokus pada visualisasi data seperti plot grafik.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#   fungsi dari kode tersebut yaitu untuk mengatur tampilan ukuran gambar setengah dari layar, apabila tidak dilakukan maka tampilan gambar akan ditampilkan full layar
# 4. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#    Berfungsi untuk memberikan garis horizontal pas pada tengah pada gambar
# 5.  Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
#    pixel menggambarkan titik terkecil gambar grafis atau citra digital dengan perhitungan per satuan metrik (inci), resolution atau resolusi merupakan jumlah pixel dalam sebuah gambar digital. Resolusi juga menunjukkan kerapatan pixel sebuah gambar.

# %% [markdown]
# #Tugas

# %% [markdown]
# 1.  Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB.)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]
  cv.line(image_3,(0,0),(255,255),(255,0,255),4)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
#   File "<ipython-input-56-b0173f321d99>", line 2
#     image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB.)
#                                                   ^
# SyntaxError: invalid syntax
